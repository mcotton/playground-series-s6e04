# %% [markdown]
# # Submission Notes

# %% [markdown]
# ## Initial Claude prompt
#
# Hi Claude, it is a new month and that means a new Kaggle competition.  We are working on "https://www.kaggle.com/competitions/playground-series-s6e4/overview" and the data is already download into @archive/  I have already started work on the code with notes in @submission_notes.ipynb.  Your job is to help me learn how I can improve and get a competitive score.  Understanding and experimentation are more important that winning.  Do not provide code unless I explicitly ask.  Do not add/modify .ipynb files directly with my permission.  Everything runs inside of docker.  Keep running notes about what have learned, what we tried, and what is still yet to try.  Save that in @exploration_options.md which we will refer to as 'md'.  Ask if you need clarification.

# %% [markdown]
# had to add a follow-up
#
# You are doing a little too much work on your own, please prompt me to investigate the data/solution before presenting your conclusions

# %% [markdown]
# ## Kaggle CLI
#
# You can submit using the Kaggle cli using this `kaggle competitions submit -f archive/submission_15.csv playground-series-s6e4`
#
# You can see your scores using this `kaggle competitions submissions playground-series-s6e4`
#
# You can get your competitions using the very poorly named command `kaggle competitions list --group entered`

# %%
from common import *

# %%
find_last_submission_file()
# Out:
# './archive/submission_05.csv'

# %% [markdown]
# | Submission | Notes | CV | LB |
# |-------------------|-------------------|-------------------|-------------------|
# | submission_01.csv | basic XGBoost |  | 0.95900 |
# | submission_02.csv | final predictions with model using all training data |  | 0.95961 |
# | submission_03.csv | added sample weights | | 0.96883 |
# | submission_04.csv | added original dataset |  | 0.96986 |
# | submission_05.csv | using original dataset formula and score went down | 0.97045 | 0.96841 |
# | submission_06.csv | keeping only high logit, score went down | 0.97010 | 0.96831 |
# | submission_07.csv | back to su bmission_04 | 0.97019 | 0.96986 |
# | submission_08.csv | limiting features to only top 6 | 0.96944 | 0.96869 |
# | submission_09.csv | adding feels_like interaction | 0.96938 | 0.96758 |
# | submission_10.csv | all features plus feels_like | 0.97040 | 0.96935 |
# | submission_11.csv | trying optuna, initial results are bad | 0.97159 | 0.96609 |
# | submission_12.csv | more optuna, cuda run | 0.97300 | 0.97045 |
